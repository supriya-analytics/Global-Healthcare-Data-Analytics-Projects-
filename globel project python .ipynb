# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\CSV FILES\project/globel.csv")

# %%
top = df.groupby("country_name")["value"].sum().sort_values(ascending=False).head(10)

# %%
df.columns
# Out:
# Index(['country_code', 'country_name', 'year', 'value'], dtype='object')

# %%
top.plot(kind="bar")
plt.show()

# %%
total_value = df['value'].sum()

# %%
print(total_value)
# Out:
# 11518178384.822823

# %%
value Per Capita =
DIVIDE(SUM(df[value]),
SUM(CO2[Population]))
