# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"D:\CSV FILES\project/healthcare.csv")
df['No-show'] = df['No-show'].map({'Yes':1,'No':0})

# %%
X = df[['Age','Scholarship','Hipertension','Diabetes','SMS_received']]
y = df['No-show']
